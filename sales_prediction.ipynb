# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read Data

# %%
sales_data=pd.read_csv("advertising.csv")
sales_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# check for nulls

# %%
sales_data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# No nulls present

# %% [markdown]
# Split data into test and train

# %%
x=sales_data.drop(columns='Sales')
y=sales_data[['Sales']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %% [markdown]
# Create Model

# %%
model1=LinearRegression()
model2=RandomForestRegressor()

# %% [markdown]
# Fit model

# %%
model1.fit(x_train,y_train)
model2.fit(x_train,y_train)
# Out:
# c:\Users\Kaustubha Ram\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %% [markdown]
# Predict

# %%
lin_pred=model1.predict(x_test)
ran_pred=model2.predict(x_test)

# %% [markdown]
# Accuracy Score

# %%
print("Linear Regression: ")
print("R2 score: ",r2_score(y_test,lin_pred))
print("Mean Absolute Error: ",mean_absolute_error(y_test,lin_pred))
print("Mean Squared Error: ",mean_squared_error(y_test,lin_pred))

print("Random Forest Regression: ")
print("R2 score: ",r2_score(y_test,ran_pred))
print("Mean Absolute Error: ",mean_absolute_error(y_test,ran_pred))
print("Mean Squared Error: ",mean_squared_error(y_test,ran_pred))
# Out:
# Linear Regression:
# R2 score:  0.8881441362855258
# Mean Absolute Error:  1.6587196157733977
# Mean Squared Error:  4.178598801682463
# Random Forest Regression:
# R2 score:  0.9573821167020434
# Mean Absolute Error:  0.9537499999999964
# Mean Squared Error:  1.592075999999993

# %%
model=model2

# %% [markdown]
# Since Random Forest Regressor gives r2_score of about 95% we use this to predict the random input

# %%
import gradio as gr
def predict(tv,radio,newspaper):
    features=[[tv,radio,newspaper]]
    prediction=model.predict(features)[0]
    return prediction
demo = gr.Interface(
    fn=predict,
    inputs=[
        "number",
        "number",
        "number",
    ],
    outputs=["number"], 
)
demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://d785823ff4e564bfeb.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d785823ff4e564bfeb.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
